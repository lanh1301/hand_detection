# %%
cd '/content/drive/MyDrive/Colab Notebooks/V2'
# Out:
# /content/drive/MyDrive/Colab Notebooks/V2

# %%
# !git clone 'https://github.com/thtrieu/darkflow.git'
# Out:
# Cloning into 'darkflow'...
# remote: Enumerating objects: 2713, done.
# remote: Total 2713 (delta 0), reused 0 (delta 0), pack-reused 2713
# Receiving objects: 100% (2713/2713), 32.98 MiB | 10.89 MiB/s, done.
# Resolving deltas: 100% (1762/1762), done.

# %%
cd darkflow
# Out:
# /content/drive/MyDrive/Colab Notebooks/V2/darkflow

# %%
# !pip install --upgrade tf_slim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install tensorflow==1.15.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/Colab%20Notebooks/V2/darkflow
# ...
#   Attempting uninstall: darkflow
#     Found existing installation: darkflow 1.0.0
#     Can't uninstall 'darkflow'. No files were found to uninstall.
#   Running setup.py develop for darkflow
# ...

# %%
# %cd 'bin'
# !wget 'https://pjreddie.com/media/files/yolov2.weights'
# Out:
# /content/drive/MyDrive/Colab Notebooks/V2/darkflow/bin
# --2022-10-05 12:26:47--  https://pjreddie.com/media/files/yolov2.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203934260 (194M) [application/octet-stream]
# Saving to: ‘yolov2.weights.1’
#
# yolov2.weights.1    100%[===================>] 194.49M  20.1MB/s    in 11s
#
# 2022-10-05 12:26:59 (18.2 MB/s) - ‘yolov2.weights.1’ saved [203934260/203934260]

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/egohands_processed.zip' -d '/content/drive/MyDrive/Colab Notebooks/V2/darkflow'
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_1875.xml
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_1898.xml
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_1951.xml
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_1984.xml
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_1998.xml
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_2046.xml
#   inflating: /content/drive/MyDrive/Colab Notebooks/V2/darkflow/egohands_processed/train/labels/CARDS_OFFICE_H_T_frame_2076.xml
# ...

# %%
# !flow --model cfg/tiny-yolo-1c.cfg --load bin/yolov2.weights
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# ...

# %%
# !flow --imgdir sample_img/ --model cfg/tiny-yolo-1c.cfg --load bin/yolov2.weights --json --gpu 1.0

# %%
# !flow --model cfg/tiny-yolo-1c.cfg --load bin/yolov2.weights  --train  --annotation egohands_processed/train/labels --dataset egohands_processed/train/images --epoch 15 --gpu 1.0 --lr 0.01
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# ...

# %%
# !flow --model cfg/tiny-yolo-1c.cfg --load bin/yolov2.weights --train  --annotation egohands_processed/train/labels --dataset egohands_processed/train/images --epoch 10 --gpu 1.0 --lr 0.000001  --load 1250
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# ...

# %%
# !flow --model cfg/tiny-yolo-1c.cfg --load 1250 --savepb --gpu 1.0
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# ...

# %%
# !flow --pbLoad built_graph/tiny-yolo-1c.pb --metaLoad built_graph/tiny-yolo-1c.meta --imgdir sample_img/
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# ...

# %%
# Forward all images in sample_img/ using tiny yolo and 100% GPU usage
# !flow --imgdir bin/sample_img/ --model cfg/tiny-yolo-voc-cus.cfg --load bin/yolov2.weights --gpu 1.0
# Out:
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:15: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:16: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:17: The name tf.train.AdagradOptimizer is deprecated. Please use tf.compat.v1.train.AdagradOptimizer instead.
#
# WARNING:tensorflow:From /content/drive/MyDrive/Colab Notebooks/V2/darkflow/darkflow/net/build.py:18: The name tf.train.AdagradDAOptimizer is deprecated. Please use tf.compat.v1.train.AdagradDAOptimizer instead.
#
# ...
